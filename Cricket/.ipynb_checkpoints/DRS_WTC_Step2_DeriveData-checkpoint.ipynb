# %% [markdown]
# ## A study to understand how teams, players and umpires have used referrals in the World Test Championship

# %% [markdown]
# ### Possible insights desired
#
# **PHASE 1**:
#
# - How effective was the DRS call in extending the survival at the crease?
#
# - No. of referrals innings wise
#
# - Who was the batting partner who has probably assited the most in DRS?
#
# **PHASE 2**:
#
# - How many recognized batsmen were left? And was there a missed opportunity due to DRS being recklessly taken earlier?**
#
# - Missed reviews by teams: Did # of remaining reviews have a say

# %% [markdown]
# ### Data points collected (Phase 1)
# -  Match in Series
# -  Series Name to produce facets
# -  Match Venue
# -  Match Date (Month_Year)
# -  Over of referral
# -  Innings of referral in game
# - Team taking review
# - Team Batting/Bowling
# - Umpire at time of review
# - Batsman at time of review
# - Outcome of review
# - Innings wise dismissal data
# - Active wicket partnership
# - Innings wise referral data (scraped from match notes, needs a bit of formatting)
# - Commentary of that particular referral ball
#
#
# ### Data points (Phase 2)
#
# - no. of recognized batsman to come vs missed opportunities for them

# %% [markdown]
# ### Required libraries

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from collections import defaultdict
import glob

# %% [markdown]
# ### Collect all match wise referral DF into one

# %%
reviews_df=pd.DataFrame()

for glob in glob.glob("review_data/*.csv"):
    df=pd.read_csv(glob)
    reviews_df=pd.concat([df,reviews_df])
    
# reviews_df.to_csv('reviews.csv',index=False)

reviews_df
# Out:
#       Over                                         commentary  \
# 0     59.5  Jadeja to Holder, out Bowled!! No luck this ti...
# 1     59.4  Jadeja to Holder, FOUR, lines up for a big hea...
# 2     59.3  Jadeja to Holder, no run, a back foot punch to...
# 3     59.2  Jadeja to Holder, no run, goes back and across...
# 4     59.1  Jadeja to Holder, no run, the intentions are w...
# ...    ...                                                ...
# 2281   0.5  Anderson to Bancroft, no run, straighter line,...
# 2282   0.4  Anderson to Bancroft, no run, back of a length...
# 2283   0.3  Anderson to Bancroft, no run, he can continue ...
# 2284   0.2  Anderson to Bancroft, no run, another away-swi...
# 2285   0.1  Anderson to Bancroft, no run, starts off with ...
#
#                       innings       keeper  captain  active_partnership  \
# 0     West Indies 2nd innings      RR Pant  V Kohli                  10
# 1     West Indies 2nd innings      RR Pant  V Kohli                  10
# 2     West Indies 2nd innings      RR Pant  V Kohli                  10
# 3     West Indies 2nd innings      RR Pant  V Kohli                  10
# 4     West Indies 2nd innings      RR Pant  V Kohli                  10
# ...                       ...          ...      ...                 ...
# 2281    Australia 1st innings  JM Bairstow  JE Root                   1
# 2282    Australia 1st innings  JM Bairstow  JE Root                   1
# 2283    Australia 1st innings  JM Bairstow  JE Root                   1
# 2284    Australia 1st innings  JM Bairstow  JE Root                   1
# 2285    Australia 1st innings  JM Bairstow  JE Root                   1
#
#      reviews Review_team Review_batsman Review_umpire Review_outcome  \
# 0        NaN         NaN            NaN           NaN            NaN
# 1        NaN         NaN            NaN           NaN            NaN
# 2        NaN         NaN            NaN           NaN            NaN
# 3        NaN         NaN            NaN           NaN            NaN
# 4        NaN         NaN            NaN           NaN            NaN
# ...      ...         ...            ...           ...            ...
# 2281     NaN         NaN            NaN           NaN            NaN
# 2282     NaN         NaN            NaN           NaN            NaN
# 2283     NaN         NaN            NaN           NaN            NaN
# 2284     NaN         NaN            NaN           NaN            NaN
# 2285     NaN         NaN            NaN           NaN            NaN
#
#      Umpires_call  index Partnership_broken  \
# 0             NaN    NaN                NaN
# 1             NaN    NaN                NaN
# 2             NaN    NaN                NaN
# 3             NaN    NaN                NaN
# 4             NaN    NaN                NaN
# ...           ...    ...                ...
# 2281          NaN    NaN                NaN
# 2282          NaN    NaN                NaN
# 2283          NaN    NaN                NaN
# 2284          NaN    NaN                NaN
# 2285          NaN    NaN                NaN
#
#                                                   match
# 0     wi-vs-ind-2nd-test-india-tour-of-west-indies-2019
# 1     wi-vs-ind-2nd-test-india-tour-of-west-indies-2019
# 2     wi-vs-ind-2nd-test-india-tour-of-west-indies-2019
# 3     wi-vs-ind-2nd-test-india-tour-of-west-indies-2019
# 4     wi-vs-ind-2nd-test-india-tour-of-west-indies-2019
# ...                                                 ...
# 2281                 eng-vs-aus-1st-test-the-ashes-2019
# 2282                 eng-vs-aus-1st-test-the-ashes-2019
# 2283                 eng-vs-aus-1st-test-the-ashes-2019
# 2284                 eng-vs-aus-1st-test-the-ashes-2019
# 2285                 eng-vs-aus-1st-test-the-ashes-2019
#
# [15457 rows x 15 columns]

# %%
# reviews_df=pd.read_csv('review_data/reviews.csv')
reviews_df['innings_action']=(reviews_df['Review_team'].astype('str')).apply(lambda x: "Batting" if "Batting" in x else "Bowling")

# %% [markdown]
# ### Process review events- to add overturned, review loss, 1st review loss, 2nd review loss logics

# %%
df=reviews_df.loc[(~pd.isnull(reviews_df.reviews))]

# df=df[df.match=='eng-vs-aus-3rd-test-the-ashes-2019']
# ##Split into innings
# reviews_df['Review_team']=reviews_df['Review_team'].astype('str')
# df=reviews_df
# df.fillna('',inplace=True)
##Keep start review count =2
## Overturn event logic. bowling-upheld and p.broken=True [OR] batting-upheld with p.broken=False 
##1st review lost at =
##2nd review lost at = 
## Review loss logic is take innings, take team batting- check upheld or struck down or struck down umpires call. add 1 if struck down
## for team bowling- check upheld or struck down or stuck down umpires call. if struck down, then add 1.

# %%
df.shape
# Out:
# (97, 16)

# %%
df['overturned']=df[['Review_team','Review_outcome','Partnership_broken']].apply(lambda x: True if 
(('Bowling' in x.Review_team and x.Review_outcome=='Upheld' and x.Partnership_broken==True) 
 or ('Batting' in x.Review_team and x.Review_outcome=='Upheld' and x.Partnership_broken==False)) else False,axis=1)
# Out:
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['review_lost']=df[['Review_team','Review_outcome','Partnership_broken']].apply(lambda x: True if 
(('Bowling' in x.Review_team and x.Review_outcome=='Struck down' and x.Partnership_broken==False) 
 or ('Batting' in x.Review_team and x.Review_outcome=='Struck down' and x.Partnership_broken==True)) else False,axis=1)
# Out:
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['first_review_lost']=(df.loc[df.review_lost==True].sort_values('Over').groupby(["match","innings","innings_action"])['review_lost'].rank('first')==1)

df['second_review_lost']=(df.loc[df.review_lost==True].sort_values('Over').groupby(["match","innings","innings_action"])['review_lost'].rank('first')==2)
# Out:
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.fillna('',inplace=True)
# Out:
# c:\users\k.shridhar\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py:4239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
# cols_to_add_from_df=['overturned','review_lost','first_review_lost','second_review_lost']

# for col in cols_to_add_from_df:
#     reviews_df[col]=df.loc[df.index,col]

# %%
# reviews_df.fillna('',inplace=True)

# %% [markdown]
# ### Visualisations for blog

# %% [markdown]
# - Batsman who took the most reviews (intiated by batsman)
# - Whom did teams take a review against the most?
# - Umpire effectiveness (# of overturned decisions/total number of DRS calls for an umpire) Bar chart
# - Review effectiveness by teams overall (Who had most partnership breaks when overturned)

# %% [markdown]
# ### Overturned decisions per match

# %%
overturned_per_match=df.groupby('match')['overturned'].sum()

# %% [markdown]
# ### Total decisions per match

# %%
total_per_match=df.groupby('match')['overturned'].count()

# %%
ot_decisions=[]

tot_avg_decisions=[]

# %%
for r in range((df.shape[0])):
    ot_decisions.append(overturned_per_match.loc[df.match.iloc[r]])
    tot_avg_decisions.append(overturned_per_match.loc[df.match.iloc[r]]/total_per_match.loc[df.match.iloc[r]])

# %%
df['overturned_decisions']=ot_decisions
# Out:
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['ratio_overturned']=tot_avg_decisions
# Out:
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# fig = px.bar(df,x='match',y='overturned_decisions')
# # fig.update_xaxes(categoryorder='sum descending')

# fig.show()

# %%
df['team']=df['Review_team'].apply(lambda x:x.split('(')[0].strip())

df['bowler']=df['commentary'].apply(lambda x:x.split(' to ')[0].strip())
# Out:
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\k.shridhar\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#      Over                                         commentary  \
# 192  27.5  Jadeja to Roston Chase, out Lbw!! Chase review...
# 222  22.5  Ishant to Roston Chase, no run, that's hooped ...
# 521  27.4  Cornwall to Rahane, no run, reviewed for the s...
# 657   4.6  Roach to Agarwal, out Lbw! Looks like he's gon...
# 704  44.2  Ishant to Roach, no run, another sharp bouncer...
#
#                      innings       keeper    captain  active_partnership  \
# 192  West Indies 2nd innings      RR Pant    V Kohli                   3
# 222  West Indies 2nd innings      RR Pant    V Kohli                   3
# 521        India 2nd innings  JN Hamilton  JO Holder                   4
# 657        India 2nd innings  JN Hamilton  JO Holder                   1
# 704  West Indies 1st innings      RR Pant    V Kohli                   9
#
#                                                reviews            Review_team  \
# 192  Over 27.5: Review by West Indies (Batting), Um...  West Indies (Batting)
# 222  Over 22.5: Review by India (Bowling), Umpire -...        India (Bowling)
# 521  Over 27.4: Review by West Indies (Bowling), Um...  West Indies (Bowling)
# 657  Over 4.6: Review by India (Batting), Umpire - ...        India (Batting)
# 704  Over 44.2: Review by India (Bowling), Umpire -...        India (Bowling)
#
#     Review_batsman     Review_umpire  ...  \
# 192       RL Chase        PR Reiffel  ...
# 222       RL Chase  RA Kettleborough  ...
# 521      AM Rahane        PR Reiffel  ...
# 657     MA Agarwal  RA Kettleborough  ...
# 704      KAJ Roach        PR Reiffel  ...
#
#                                                  match  innings_action  \
# 192  wi-vs-ind-2nd-test-india-tour-of-west-indies-2019         Batting
# 222  wi-vs-ind-2nd-test-india-tour-of-west-indies-2019         Bowling
# 521  wi-vs-ind-2nd-test-india-tour-of-west-indies-2019         Bowling
# 657  wi-vs-ind-2nd-test-india-tour-of-west-indies-2019         Batting
# 704  wi-vs-ind-2nd-test-india-tour-of-west-indies-2019         Bowling
#
#      overturned  review_lost first_review_lost second_review_lost  \
# 192       False        False
# 222       False         True              True              False
# 521       False         True              True              False
# 657       False        False
# 704       False         True              True              False
#
#      overturned_decisions  ratio_overturned         team    bowler
# 192                   2.0          0.222222  West Indies    Jadeja
# 222                   2.0          0.222222        India    Ishant
# 521                   2.0          0.222222  West Indies  Cornwall
# 657                   2.0          0.222222        India     Roach
# 704                   2.0          0.222222        India    Ishant
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (97, 24)

# %%
df.to_excel('data/reviews_pbi.xlsx',index=False)

# %%
reviews_df.fillna('',inplace=True)

reviews_df.to_excel('data/all_match_events.xlsx',index=False)
